# %%
import pandas as pd
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AI /diamondd.csv')

print(dataset.head())
X = dataset[['carat','depth','table','x','y']]
Y = dataset[['price']]



x = X.values
y = Y.values


x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.50, random_state=42)


from sklearn import linear_model
lr = linear_model.LinearRegression()

lr.fit(x_train, y_train)

predicted=lr.predict(x_test)


print("Predict value " + str(predicted))
print("Real value " + str(y_test))



#print("Accuracy: ",lr.score(x_test, y_test)*100)

print('r2_score: ',skl.metrics.r2_score(y_test,predicted)*100)
print('explained_variance_score: ',skl.metrics.explained_variance_score(y_test,predicted)*100)
print('mean_gamma_deviance: ',skl.metrics.mean_gamma_deviance(y_test,predicted)*100)
print('mean_absolute_percentage_error',skl.metrics.mean_absolute_percentage_error(y_test,predicted)*100)
# Out:
#    num  carat  depth  table     x     y  price
# 0    1   0.23   61.5   55.0  3.95  3.56   3000
# 1    2   0.21   59.8   61.0  3.89  4.30   3200
# 2    3   0.23   56.9   65.0  4.05  3.80   3450
# 3    4   0.29   62.4   58.0  4.20  3.98   6500
# 4    5   0.31   63.3   58.0  4.34  3.87   3200
# Predict value [[5141.15077245]
#  [4327.05302555]
#  [3401.51554941]
#  [5445.48169567]
#  [4967.35967837]
#  [5182.91876932]
#  [3623.33070738]
#  [4974.75827787]
#  [5248.69348733]
#  [4494.67875109]
#  [4352.67279569]
#  [5023.22404581]
#  [5546.52088709]
#  [4134.83519825]
#  [5586.06317043]
#  [4971.62316936]
#  [4867.43325215]
#  [5556.88379486]
#  [3958.39288765]
#  [4591.25377709]
#  [5725.1654425 ]
#  [4121.84020748]
#  [5130.94803258]
#  [5302.24133524]
#  [3867.03280103]
#  [4583.00801321]
#  [3898.00157331]
#  [4764.68711369]
#  [5469.01650585]
#  [5474.08652503]
#  [3776.10709061]
#  [4411.796852  ]
#  [4399.91846188]
#  [4093.46111097]
#  [5523.36479177]
#  [5259.30129932]
#  [5691.95758141]
#  [5447.14883125]
#  [5192.57241453]
#  [3820.76082728]
#  [4211.36553068]
#  [5698.82022721]
#  [4087.52483274]
#  [4545.64817903]
#  [5826.81261978]
#  [5768.40641845]
#  [3481.48755282]
#  [4407.91583384]
#  [5429.23056537]
#  [3758.01917627]
#  [5383.68584139]
#  [5165.34181744]
#  [3669.81802329]
#  [3928.59679497]
#  [5126.11339654]
#  [4497.45020986]
#  [5413.94420008]
#  [5496.74415091]
#  [4006.57487505]
#  [5440.80503718]
#  [5658.94286263]
#  [6168.93739841]
#  [3562.71548406]
#  [3553.73401507]
#  [3489.82286945]
#  [5194.64352334]
#  [4168.27253155]
#  [5426.08164323]
#  [5586.90463831]
#  [5629.52742008]
#  [3178.62670744]
#  [5474.7835336 ]
#  [5755.40991646]
#  [4560.66475924]
#  [5384.23504753]
#  [5297.49104998]
#  [4204.05613748]
#  [5348.42572829]
#  [5390.89857552]
#  [5276.09359274]
#  [3833.19848718]
#  [3623.2517186 ]
#  [4054.2465748 ]
#  [5332.40189692]
#  [5193.50898406]
#  [3872.35126068]
#  [5146.91818211]
#  [3892.87977787]
#  [5427.69438802]
#  [4469.88377227]
#  [3321.97546308]
#  [5557.49625141]
#  [5278.53439234]
#  [3454.65033704]
#  [3690.27080507]
#  [5406.78912445]
#  [5572.84295622]
#  [3488.06622853]
#  [4365.06030138]
#  [5405.70936145]]
# Real value [[2697]
#  [5890]
#  [9860]
#  [4876]
#  [1276]
#  [2575]
#  [5690]
#  [7650]
#  [3637]
#  [1480]
#  [3580]
#  [7647]
#  [8470]
#  [1680]
#  [6535]
#  [6353]
#  [2230]
#  [8654]
#  [3890]
#  [2680]
#  [4578]
#  [2380]
#  [4798]
#  [2390]
#  [3690]
#  [3680]
#  [3679]
#  [1270]
#  [2390]
#  [4578]
#  [6780]
#  [4570]
#  [5670]
#  [3780]
#  [4797]
#  [2680]
#  [ 578]
#  [3464]
#  [5798]
#  [2589]
#  [3680]
#  [3685]
#  [3480]
#  [5090]
#  [2376]
#  [4087]
#  [1290]
#  [2390]
#  [3674]
#  [5680]
#  [3578]
#  [3536]
#  [3450]
#  [5690]
#  [4597]
#  [3890]
#  [9753]
#  [1580]
#  [5649]
#  [3480]
#  [8640]
#  [3690]
#  [7850]
#  [3670]
#  [2376]
#  [1298]
#  [3489]
#  [6645]
#  [1290]
#  [6789]
#  [4580]
#  [2390]
#  [8734]
#  [1290]
#  [2568]
#  [5785]
#  [6794]
#  [2577]
#  [3789]
#  [3578]
#  [3450]
#  [3578]
#  [4570]
#  [6435]
#  [3369]
#  [1235]
#  [9657]
#  [3678]
#  [9874]
#  [3570]
#  [8000]
#  [4676]
#  [2690]
#  [2470]
#  [1230]
#  [5785]
#  [9875]
#  [7890]
#  [3970]
#  [3478]]
# r2_score:  -9.257314596842603
# explained_variance_score:  -6.790786578306318
# mean_gamma_deviance:  31.998853495450742
# mean_absolute_percentage_error 71.49599350395494

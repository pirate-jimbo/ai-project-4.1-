# %%
import pandas as pd
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AI /diamondd.csv')

print(dataset.head())
X = dataset[['carat','depth','table','x','y']]
Y = dataset[['price']]



x = X.values
y = Y.values
print(X)

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.50, random_state=42)

#from sklearn.datasets import load_boston
from sklearn.linear_model import Lasso


lm = Lasso(alpha=1.0)

lm.fit(x_train, y_train)

predicted=lm.predict(x_test)


print("Predict value " + str(predicted))
print("Real value " + str(y_test))


#print("Accuracy: ",gbr.score(x_test, y_test)*100)

print('r2_score: ',skl.metrics.r2_score(y_test,predicted)*100)
print('explained_variance_score: ',skl.metrics.explained_variance_score(y_test,predicted)*100)
print('mean_gamma_deviance: ',skl.metrics.mean_gamma_deviance(y_test,predicted)*100)
print('mean_absolute_percentage_error',skl.metrics.mean_absolute_percentage_error(y_test,predicted)*100)
# Out:
#    num  carat  depth  table     x     y  price
# 0    1   0.23   61.5   55.0  3.95  3.56   3000
# 1    2   0.21   59.8   61.0  3.89  4.30   3200
# 2    3   0.23   56.9   65.0  4.05  3.80   3450
# 3    4   0.29   62.4   58.0  4.20  3.98   6500
# 4    5   0.31   63.3   58.0  4.34  3.87   3200
#      carat  depth  table     x     y
# 0     0.23   61.5   55.0  3.95  3.56
# 1     0.21   59.8   61.0  3.89  4.30
# 2     0.23   56.9   65.0  4.05  3.80
# 3     0.29   62.4   58.0  4.20  3.98
# 4     0.31   63.3   58.0  4.34  3.87
# ..     ...    ...    ...   ...   ...
# 195   0.70   62.7   59.0  5.67  4.23
# 196   0.70   61.0   57.0  5.73  4.87
# 197   0.70   61.0   58.0  5.78  3.76
# 198   0.70   61.4   57.0  5.76  3.55
# 199   0.72   61.8   61.0  5.82  4.76
#
# [200 rows x 5 columns]
# Predict value [5156.9020792  4322.70152114 3509.0327835  5437.62543661 5136.67575162
#  5177.48758751 3708.43160362 5039.86094596 5236.72976907 4451.94520984
#  4321.19639425 5068.35659599 5526.1580653  4165.57949714 5543.4785149
#  5037.63096155 4778.22443074 5543.72058166 4001.50939336 4537.88075919
#  5637.75797992 4110.09134117 5164.39375531 5304.70301942 3909.58943517
#  4536.35765765 3950.55579755 4675.9794857  5463.14243373 5463.25896168
#  3853.41362286 4374.87386523 4383.39630824 4115.95204357 5502.63765839
#  5305.18179742 5608.33032125 5440.81253258 5231.46094231 3875.88162713
#  4217.03937105 5627.63476185 4107.95408935 4524.8540559  5786.43155089
#  5702.65979669 3578.76552449 4397.5474523  5393.05776441 3820.66374916
#  5371.61229153 5116.19011858 3745.14942527 4264.68516832 5130.26766375
#  4449.30465704 5389.36435741 5490.12646597 4499.47382063 5450.78796848
#  5623.68011536 6201.76254969 3639.9346329  3671.02705541 3593.71563245
#  5269.71783194 4162.7176201  5422.01264488 5532.86071748 5612.88059057
#  3304.83762658 5384.97081526 5712.07705489 4499.12490147 5369.55848111
#  5334.82221674 4184.92635338 5296.18605506 5389.81877048 5286.79419345
#  3929.41711264 3684.78729191 4073.46257964 5338.5605009  5189.04209851
#  3929.08595974 5163.45624038 3948.93206818 5417.53841719 4447.58873173
#  3448.05021984 5491.62103413 5263.14984881 3560.51416837 3747.29164526
#  5380.15476757 5524.61181882 3593.47258226 4339.82959226 5378.60932244]
# Real value [[2697]
#  [5890]
#  [9860]
#  [4876]
#  [1276]
#  [2575]
#  [5690]
#  [7650]
#  [3637]
#  [1480]
#  [3580]
#  [7647]
#  [8470]
#  [1680]
#  [6535]
#  [6353]
#  [2230]
#  [8654]
#  [3890]
#  [2680]
#  [4578]
#  [2380]
#  [4798]
#  [2390]
#  [3690]
#  [3680]
#  [3679]
#  [1270]
#  [2390]
#  [4578]
#  [6780]
#  [4570]
#  [5670]
#  [3780]
#  [4797]
#  [2680]
#  [ 578]
#  [3464]
#  [5798]
#  [2589]
#  [3680]
#  [3685]
#  [3480]
#  [5090]
#  [2376]
#  [4087]
#  [1290]
#  [2390]
#  [3674]
#  [5680]
#  [3578]
#  [3536]
#  [3450]
#  [5690]
#  [4597]
#  [3890]
#  [9753]
#  [1580]
#  [5649]
#  [3480]
#  [8640]
#  [3690]
#  [7850]
#  [3670]
#  [2376]
#  [1298]
#  [3489]
#  [6645]
#  [1290]
#  [6789]
#  [4580]
#  [2390]
#  [8734]
#  [1290]
#  [2568]
#  [5785]
#  [6794]
#  [2577]
#  [3789]
#  [3578]
#  [3450]
#  [3578]
#  [4570]
#  [6435]
#  [3369]
#  [1235]
#  [9657]
#  [3678]
#  [9874]
#  [3570]
#  [8000]
#  [4676]
#  [2690]
#  [2470]
#  [1230]
#  [5785]
#  [9875]
#  [7890]
#  [3970]
#  [3478]]
# r2_score:  -7.526743315418649
# explained_variance_score:  -4.832358410099125
# mean_gamma_deviance:  31.429723681838574
# mean_absolute_percentage_error 71.21251286659279
